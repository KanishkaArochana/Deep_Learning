# %%
# Import Necessary Libraries
import pandas as pd # Do data fram
import tensorflow as tf # For model build
from sklearn.preprocessing import LabelEncoder # Convert Text format value to Numarical value
from sklearn.preprocessing import MinMaxScaler # Future scaling

# %%
# Load Dataset
data = pd.read_csv('sonar.csv', header=None)
data = data.values

# %%
data[:1] # One data recode in dataset
# Out:
# array([[0.02, 0.0371, 0.0428, 0.0207, 0.0954, 0.0986, 0.1539, 0.1601,
#         0.3109, 0.2111, 0.1609, 0.1582, 0.2238, 0.0645, 0.066, 0.2273,
#         0.31, 0.2999, 0.5078, 0.4797, 0.5783, 0.5071, 0.4328, 0.555,
#         0.6711, 0.6415, 0.7104, 0.808, 0.6791, 0.3857, 0.1307, 0.2604,
#         0.5121, 0.7547, 0.8537, 0.8507, 0.6692, 0.6097, 0.4943, 0.2744,
#         0.051, 0.2834, 0.2825, 0.4256, 0.2641, 0.1386, 0.1051, 0.1343,
#         0.0383, 0.0324, 0.0232, 0.0027, 0.0065, 0.0159, 0.0072, 0.0167,
#         0.018, 0.0084, 0.009, 0.0032, 'R']], dtype=object)

# %%
# Divide dataset into x and y
X = data[:, 0:60].astype(float) # # Separate features (first 60 columns)
y = data[:, 60] # target (last column) from dataset (61st column) and Target labels (60 index[R --> have Numaric value] )

# %%
# Y values Encode Labels (Convert numarical)
encoder = LabelEncoder()
encoder.fit(y)
Y = encoder.transform(y)

# %%
# X value Adapting to the same scale
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
# Divide dataset into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state= 42)

# %% [markdown]
# ## **Create Model**

# %%
tf.random.set_seed(42)

# create a model with dropout Layers  (This is binary classification problem)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(30, activation='relu', input_shape=(60, )), # have input 60 values in one data recode
    tf.keras.layers.Dropout(0.2), # Add Dropout layer (0.2 ---> 2/10 deactivate)
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(30, activation='relu'),  # Use for 4 hidden layers
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid') # Output Layer
    ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(loss= tf.keras.losses.BinaryCrossentropy(),
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.005),
              metrics=['accuracy'])

# %%
# Train the model
epoch_number = 100
history = model.fit(X_train, y_train, epochs = epoch_number) #  Look at Test Loss and Accurancy
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4339 - loss: 0.7050
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5184 - loss: 0.6882
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6131 - loss: 0.6830
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5261 - loss: 0.6852
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6076 - loss: 0.6614
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6436 - loss: 0.6344
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6153 - loss: 0.6396
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7487 - loss: 0.5738
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7454 - loss: 0.5353
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7946 - loss: 0.4711
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7337 - loss: 0.5018
# Epoch 12/100
# ...

# %%
# Evaluate the model
model.evaluate(X_test, y_test) # Look at Test Loss and Accurancy
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8631 - loss: 0.4503
# [0.47627612948417664, 0.8571428656578064]
